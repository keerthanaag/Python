# %% [markdown]
# # HIGHER OR LOWER

# %% [markdown]
# #### dictionary

# %%
#used formatter from online for the above dictionary
products = {
    "Chanel": 8349483,
    "Dior": 14842442,
    "Yves Saint Laurent (YSL)": 95437647,
    "Giorgio Armani Beauty": 64652936,
    "Guerlain": 44258733,
    "Estée Lauder": 93457983,
    "MAC Cosmetics": 57483,
    "Urban Decay": 47284,
    "NARS": 24829,
    "Smashbox": 43984,
    "Benefit Cosmetics": 49965,
    "Tarte": 94722,
    "Maybelline New York": 4385,
    "L'Oréal Paris": 9274,
    "Revlon": 8742,
    "NYX Professional Makeup": 9920,
    "CoverGirl": 9164,
    "e.l.f. Cosmetics": 9874,
    "Glossier": 394,
    "Fenty Beauty by Rihanna": 1254,
    "Huda Beauty": 3785,
    "Anastasia Beverly Hills": 7812,
    "Milk Makeup": 2786,
    "The Balm": 6478,
    "Shiseido": 980,
    "Etude House": 565,
    "Laneige": 457,
    "Innisfree": 665,
    "Sulwhasoo": 658,
}

# %% [markdown]
# #### guess function

# %%
def guess(a):
    print("Find which has more followers on instagram")
    b=random.choice(list(products.keys()))
    #print(b)
    while(a==b):
        if a == b:
            b=random.choice(list(products.keys()))
    print(f"A = {a}\tB = {b}")
    guess=input("Enter you choice:'{a/b}'\t")
    if guess.lower() in ['a','b']:
        if products[a]>products[b]:
            ans='a'
            last=a
        else:
            ans='b'
            last=b
        if ans==guess.lower():
            a=last
            print(f"correct guess is {ans}")
            return [last,1]
        else:
            return []
    else:
        return []

# %% [markdown]
# #### execution starts

# %%
import random
wins=0
a=random.choice(list(products.keys()))
#print(a)
while(1):
    output=guess(a)
    if len(output)==0:
        print(f"You have made {wins} correct guesses")
        break
    else:
        wins+=output[1]
        a=output[0]
# Out:
# Find which has more followers on instagram
# A = Anastasia Beverly Hills	B = Dior
# Enter you choice:'{a/b}'	b
# correct guess is b
# Find which has more followers on instagram
# A = Dior	B = Yves Saint Laurent (YSL)
# Enter you choice:'{a/b}'	b
# correct guess is b
# Find which has more followers on instagram
# A = Yves Saint Laurent (YSL)	B = Smashbox
# Enter you choice:'{a/b}'	a
# correct guess is a
# Find which has more followers on instagram
# A = Yves Saint Laurent (YSL)	B = Laneige
# Enter you choice:'{a/b}'	a
# correct guess is a
# Find which has more followers on instagram
# A = Yves Saint Laurent (YSL)	B = Sulwhasoo
